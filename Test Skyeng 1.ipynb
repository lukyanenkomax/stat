# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
# Data manipulation
import pandas as pd
import numpy as np
import scipy

# Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Data analysis

# %%
data=pd.read_csv('../lukya/downloads/test_1_1.csv',sep=';')

# %% [markdown]
# % наблюдений, который выходит за 05 и 95 квантиль

# %%
len(data.loc[(data['metrics']<=data.loc[:,['metrics']].quantile(q=0.05)[0])| 
             (data['metrics']>=data.loc[:,['metrics']].quantile(q=0.95)[0])])/len(data)*100
# Out:
# 48.16499858231841

# %% [markdown]
# ###График распределения данных без выбросов (x<100)

# %%
sns.distplot(data.loc[data['metrics']<100,'metrics']);

# %%
sns.distplot(scipy.stats.logser.rvs(0.899,0,300000));

# %% [markdown]
# Распределение ближе всего к логарифмическому
